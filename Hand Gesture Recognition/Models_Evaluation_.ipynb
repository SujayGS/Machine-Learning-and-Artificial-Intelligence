# %% [markdown]
# # VGG-16 Model Confusion Matrix & Classification Report

# %%
#Importing necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# Load your saved CNN model
model = load_model('/content/drive/MyDrive/DS/Demodata/VGG16_Dec17.h5')

# Directory containing your test data images
test_data_dir = '/content/drive/MyDrive/DS/Test_NEW_SK_A_Z_1_9'

# List of class labels (folder names) in your test data directory
class_labels = sorted(os.listdir(test_data_dir))

# Load your own test data
test_images = []
true_labels = []

# Loop through each class label (folder)
for label_idx, label in enumerate(class_labels):
    label_dir = os.path.join(test_data_dir, label)

    # Loop through each image in the current class
    for img_file in os.listdir(label_dir):
        img_path = os.path.join(label_dir, img_file)
        img = load_img(img_path, target_size=(32,32))
        img_array = img_to_array(img)
        test_images.append(img_array)
        true_labels.append(label_idx)

# Convert lists to NumPy arrays
test_images = np.array(test_images)
true_labels = np.array(true_labels)

# Normalize pixel values (optional, depends on your model)
test_images = test_images / 255.0

# Make predictions
predictions = model.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Accuracy: {accuracy:.2f}")

# Plot confusion matrix
plt.figure(figsize=(14,14))  # Set the figure size to your preferred dimensions

# Create a confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix
label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=class_names)
ax = plt.gca()
disp.plot(cmap=plt.cm.Blues, values_format=".0f", ax=ax)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# Display classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# 550/550 [==============================] - 288s 523ms/step
# Accuracy: 0.80
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.85      0.92      0.88       528
#            2       0.65      0.76      0.70       494
#            3       0.98      0.49      0.65       558
#            4       0.67      0.97      0.79       481
#            5       0.91      1.00      0.95       520
#            6       0.78      0.90      0.83       521
#            7       0.75      0.72      0.74       585
#            8       0.71      0.91      0.80       572
#            9       0.88      0.75      0.81       520
#            A       0.87      0.80      0.83       415
#            B       0.92      0.98      0.95       432
#            C       1.00      1.00      1.00       398
#            D       0.92      0.94      0.93       438
#            E       0.97      0.73      0.84       570
#            F       0.97      0.99      0.98       528
#            G       0.89      0.85      0.87       450
#            H       0.81      0.98      0.89       484
#            I       0.05      0.00      0.01       511
#            J       1.00      0.99      0.99       561
#            K       0.80      0.92      0.86       506
#            L       0.83      0.80      0.81       462
#            M       0.74      0.99      0.85       528
#            N       0.52      1.00      0.69       506
#            O       0.98      1.00      0.99       570
#            P       1.00      0.92      0.96       495
#            Q       0.98      0.98      0.98       474
#            R       0.94      0.96      0.95       462
#            S       0.94      0.74      0.83       506
#            T       0.50      1.00      0.67       484
#            U       0.59      0.98      0.74       506
#            V       0.68      0.23      0.34       440
#            W       0.30      0.05      0.09       495
#            X       0.71      0.73      0.72       506
#            Y       0.93      0.99      0.96       561
#            Z       1.00      0.11      0.19       517
#
#     accuracy                           0.80     17584
#    macro avg       0.80      0.80      0.77     17584
# weighted avg       0.80      0.80      0.77     17584

# %% [markdown]
# # Custom Model Confusion Matrix & Classification Report

# %%
#Import necessary libraries
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# Load your saved CNN model
model_1 = load_model('/content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5')

# Directory containing your test data images
test_data_dir = '/content/drive/MyDrive/DS/Test_NEW_SK_A_Z_1_9'

# List of class labels (folder names) in your test data directory
class_labels = sorted(os.listdir(test_data_dir))

# Load your own test data
test_images = []
true_labels = []

# Loop through each class label (folder)
for label_idx, label in enumerate(class_labels):
    label_dir = os.path.join(test_data_dir, label)

    # Loop through each image in the current class
    for img_file in os.listdir(label_dir):
        img_path = os.path.join(label_dir, img_file)
        img = load_img(img_path, target_size=(32,32))  # Adjust target_size if needed
        img_array = img_to_array(img)
        test_images.append(img_array)
        true_labels.append(label_idx)

# Convert lists to NumPy arrays
test_images = np.array(test_images)
true_labels = np.array(true_labels)

# Normalize pixel values (optional, depends on your model)
test_images = test_images / 255.0

# Make predictions
predictions = model_1.predict(test_images)
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(true_labels, predicted_labels)
print(f"Accuracy: {accuracy:.2f}")

# Plot confusion matrix
plt.figure(figsize=(14,14))  # Set the figure size to your preferred dimensions

# Create a confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix
label_encoder = LabelEncoder()
label_encoder.fit(class_labels)
class_names = label_encoder.classes_
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=class_names)
ax = plt.gca()
disp.plot(cmap=plt.cm.Blues, values_format=".0f", ax=ax)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# Display classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# 550/550 [==============================] - 15s 27ms/step
# Accuracy: 0.87
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.92      0.87       528
#            2       0.91      0.89      0.90       494
#            3       0.94      0.55      0.69       558
#            4       0.66      0.60      0.63       481
#            5       0.73      1.00      0.85       520
#            6       0.97      0.22      0.36       521
#            7       0.93      0.98      0.95       585
#            8       0.86      0.97      0.91       572
#            9       0.78      0.87      0.82       520
#            A       0.97      0.73      0.83       415
#            B       0.97      0.99      0.98       432
#            C       0.95      1.00      0.97       398
#            D       0.77      0.99      0.87       438
#            E       0.99      1.00      0.99       570
#            F       0.90      1.00      0.95       528
#            G       0.96      0.64      0.77       450
#            H       0.75      0.96      0.84       484
#            I       0.97      0.64      0.77       511
#            J       0.94      1.00      0.97       561
#            K       0.97      0.99      0.98       506
#            L       0.64      0.71      0.67       462
#            M       0.88      1.00      0.94       528
#            N       0.83      1.00      0.91       506
#            O       0.98      1.00      0.99       570
#            P       0.98      1.00      0.99       495
#            Q       0.99      1.00      1.00       474
#            R       1.00      1.00      1.00       462
#            S       0.99      0.84      0.91       506
#            T       0.91      0.99      0.95       484
#            U       0.63      1.00      0.77       506
#            V       0.80      0.64      0.71       440
#            W       0.56      0.63      0.59       495
#            X       1.00      0.67      0.80       506
#            Y       0.99      1.00      0.99       561
#            Z       1.00      0.98      0.99       517
#
#     accuracy                           0.87     17584
#    macro avg       0.88      0.87      0.86     17584
# weighted avg       0.89      0.87      0.86     17584

# %% [markdown]
# # VGG-16 Model ROC-AUC Evaluation Code

# %%
#Import necessary libraries
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Convert labels to binary matrix for Model
true_labels_bin_model = label_binarize(true_labels, classes=list(range(len(class_labels))))

# Make predictions for Model
predictions_probs_model = model.predict(test_images)

# Compute ROC curve and ROC area for each class in Model
fpr_model = dict()
tpr_model = dict()
roc_auc_model = dict()

for i in range(len(class_labels)):
    fpr_model[i], tpr_model[i], _ = roc_curve(true_labels_bin_model[:, i], predictions_probs_model[:, i])
    roc_auc_model[i] = auc(fpr_model[i], tpr_model[i])
    print(f'AUC for {class_labels[i]}: {roc_auc_model[i]:.2f}')

# Compute micro-average ROC curve and ROC area for Model
fpr_model["micro"], tpr_model["micro"], _ = roc_curve(true_labels_bin_model.ravel(), predictions_probs_model.ravel())
roc_auc_model["micro"] = auc(fpr_model["micro"], tpr_model["micro"])
print(f'Micro-average AUC: {roc_auc_model["micro"]:.2f}')

# Plot ROC curves for each class
plt.figure(figsize=(12, 8))
lw = 2
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'purple', 'green', 'red', 'brown', 'pink', 'gray', 'olive'])

# Iterate over each class and plot ROC curve
for i, color in zip(range(len(class_labels)), colors):
    plt.plot(fpr_model[i], tpr_model[i], color=color, lw=lw, label=f'ROC curve (area = {roc_auc_model[i]:.2f}) for {class_labels[i]}')

# Plot micro-average ROC curve
plt.plot(fpr_model["micro"], tpr_model["micro"], color='deeppink', lw=lw, linestyle='--', label=f'micro-average ROC curve (area = {roc_auc_model["micro"]:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for VGG-16 Model')

# Display legend separately outside the plot
plt.legend(labels=class_labels, loc="center left", bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# 550/550 [==============================] - 251s 456ms/step
# AUC for 1: 0.99
# AUC for 2: 0.99
# AUC for 3: 0.97
# AUC for 4: 0.99
# AUC for 5: 1.00
# AUC for 6: 0.99
# AUC for 7: 0.97
# AUC for 8: 0.96
# AUC for 9: 1.00
# AUC for A: 1.00
# AUC for B: 1.00
# AUC for C: 1.00
# AUC for D: 1.00
# AUC for E: 1.00
# AUC for F: 1.00
# AUC for G: 0.99
# AUC for H: 0.99
# AUC for I: 0.63
# AUC for J: 1.00
# AUC for K: 0.99
# AUC for L: 0.98
# AUC for M: 1.00
# AUC for N: 1.00
# AUC for O: 1.00
# AUC for P: 1.00
# AUC for Q: 1.00
# AUC for R: 1.00
# AUC for S: 0.99
# AUC for T: 1.00
# AUC for U: 1.00
# AUC for V: 0.94
# AUC for W: 0.82
# AUC for X: 0.96
# AUC for Y: 0.99
# AUC for Z: 0.98
# Micro-average AUC: 0.97

# %% [markdown]
# # Custom Model ROC-AUC Evaluation Code

# %%
#Import necessary libraries
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Convert labels to binary matrix for Model
true_labels_bin_model_1 = label_binarize(true_labels, classes=list(range(len(class_labels))))

# Make predictions for Model
predictions_probs_model_1 = model_1.predict(test_images)

# Compute ROC curve and ROC area for each class in Model
fpr_model = dict()
tpr_model = dict()
roc_auc_model = dict()

for i in range(len(class_labels)):
    fpr_model[i], tpr_model[i], _ = roc_curve(true_labels_bin_model_1[:, i], predictions_probs_model_1[:, i])
    roc_auc_model[i] = auc(fpr_model[i], tpr_model[i])
    print(f'AUC for {class_labels[i]}: {roc_auc_model[i]:.2f}')

# Compute micro-average ROC curve and ROC area for Model
fpr_model["micro"], tpr_model["micro"], _ = roc_curve(true_labels_bin_model_1.ravel(), predictions_probs_model_1.ravel())
roc_auc_model["micro"] = auc(fpr_model["micro"], tpr_model["micro"])
print(f'Micro-average AUC: {roc_auc_model["micro"]:.2f}')

# Plot ROC curves for each class
plt.figure(figsize=(12, 8))
lw = 2
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'purple', 'green', 'red', 'brown', 'pink', 'gray', 'olive'])

# Iterate over each class and plot ROC curve
for i, color in zip(range(len(class_labels)), colors):
    plt.plot(fpr_model[i], tpr_model[i], color=color, lw=lw, label=f'ROC curve (area = {roc_auc_model[i]:.2f}) for {class_labels[i]}')

# Plot micro-average ROC curve
plt.plot(fpr_model["micro"], tpr_model["micro"], color='deeppink', lw=lw, linestyle='--', label=f'micro-average ROC curve (area = {roc_auc_model["micro"]:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for VGG-16 Model')

# Display legend separately outside the plot
plt.legend(labels=class_labels, loc="center left", bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# 550/550 [==============================] - 15s 27ms/step
# AUC for 1: 1.00
# AUC for 2: 1.00
# AUC for 3: 1.00
# AUC for 4: 0.99
# AUC for 5: 1.00
# AUC for 6: 0.99
# AUC for 7: 1.00
# AUC for 8: 1.00
# AUC for 9: 1.00
# AUC for A: 1.00
# AUC for B: 1.00
# AUC for C: 1.00
# AUC for D: 1.00
# AUC for E: 1.00
# AUC for F: 1.00
# AUC for G: 1.00
# AUC for H: 1.00
# AUC for I: 1.00
# AUC for J: 1.00
# AUC for K: 1.00
# AUC for L: 0.99
# AUC for M: 1.00
# AUC for N: 1.00
# AUC for O: 1.00
# AUC for P: 1.00
# AUC for Q: 1.00
# AUC for R: 1.00
# AUC for S: 1.00
# AUC for T: 1.00
# AUC for U: 1.00
# AUC for V: 0.99
# AUC for W: 0.98
# AUC for X: 1.00
# AUC for Y: 1.00
# AUC for Z: 1.00
# Micro-average AUC: 1.00

# %% [markdown]
# # Comparing AUC score - VGG-16 vs Custom Model

# %%
#Import necessary libraries
from sklearn.metrics import roc_auc_score

# Assuming you have the test data and true labels loaded

# Calculate AUC for Model
auc_model = roc_auc_score(true_labels_bin_model, predictions_probs_model)
# Calculate AUC for Model1
auc_model1 = roc_auc_score(true_labels_bin_model_1, predictions_probs_model_1)

# Plot AUC curves
plt.figure(figsize=(10, 6))
models = ['VGG-16', 'Custom Model']
auc_scores = [auc_model, auc_model1]

plt.bar(models, auc_scores, color=['blue', 'orange'])
plt.ylim([0.0, 1.0])
plt.ylabel('AUC Score')
plt.title('Area Under the Curve (AUC) for Models')
plt.show()
