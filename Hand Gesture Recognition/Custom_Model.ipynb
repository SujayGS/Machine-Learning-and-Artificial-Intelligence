# %%
#Importing necessary libraries

import tensorflow as tf
import os, keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import imgaug.augmenters as iaa
import numpy as np
from tensorflow.keras.regularizers import l2

# %%
# Define the path to the data directory

data_dir = '/content/drive/MyDrive/DS/Final_Dataset_A_Z_SK_NewSign'
test_dir = '/content/drive/MyDrive/DS/Test_NEW_SK_A_Z_1_9'
IMAGE_SIZE=32
BATCH_SIZE=32

# Calculate the split sizes
train_split = 0.7
val_split = 0.2
test_split = 0.1

# Get the total number of images
total_images = sum([len(files) for r, d, files in os.walk(data_dir)])

# Calculate the number of images for each split
train_size = int(total_images * train_split)
val_size = int(total_images * val_split)
test_size = int(total_images * test_split)

# Calculate the steps per epoch for training and validation
train_steps_per_epoch = train_size // BATCH_SIZE
val_steps_per_epoch = val_size // BATCH_SIZE
test_steps_per_epoch = test_size // BATCH_SIZE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data generator for training set for Custom Model
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3],
    validation_split=0.3
)

# Data generator for validation set
val_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=val_split
)

# Data generator for testing set (no data augmentation)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                               rotation_range=10,
                                                               width_shift_range=0.1,
                                                                height_shift_range=0.1,
                                                               horizontal_flip=True,
                                                                shear_range=0.1,
                                                                  zoom_range=0.1,
                                                               brightness_range=[0.7, 1.3],
    channel_shift_range=5,  # Color Jittering
    preprocessing_function=lambda x: x + np.random.normal(0, 0.1, x.shape),
)

# %%
# Load the data for training set
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

#Load the data for validation set
validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)

# Load the data for testing set
test_generator = test_datagen.flow_from_directory(
test_dir,
target_size=(IMAGE_SIZE,IMAGE_SIZE),
batch_size=BATCH_SIZE,
class_mode='categorical',
shuffle=False,
)
# Out:
# Found 53528 images belonging to 35 classes.
# Found 22924 images belonging to 35 classes.
# Found 17584 images belonging to 35 classes.

# %%
# Extracting class labels from the training generator
labels = [k for k in train_generator.class_indices]

# Generating a batch of samples from the training generator
sample_generate = train_generator.next()

# Extracting images and titles (labels) from the generated batch
images = sample_generate[0]
titles = sample_generate[1]

# Creating a Matplotlib figure
plt.figure(figsize=(32, 32))

# Looping through the images and titles to create subplots
for i in range(20):
    # Creating a subplot
    plt.subplot(20, 20, i + 1)

    # Adjusting subplot spacing
    plt.subplots_adjust(hspace=0.3, wspace=0.3)

    # Displaying the image
    plt.imshow(images[i])

    # Displaying the class label as the title
    plt.title(f'Class: {labels[np.argmax(titles[i], axis=0)]}')

    # Turning off axis for better visualization
    plt.axis("off")

# Showing the plot
plt.show()

# %%
# Creating a Sequential model
model = Sequential()

# First Convolutional Layer
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)))
model.add(BatchNormalization())  # Batch normalization to normalize the activations
model.add(MaxPooling2D(2, strides=2))  # MaxPooling to downsample the spatial dimensions

# Second Convolutional Layer
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', groups=1))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, strides=2))

# Third Convolutional Layer
model.add(Conv2D(16, (3, 3), activation='relu', padding='same', groups=1))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, strides=2))

# %%
# Flatten the output from the convolutional layers
model.add(Flatten())

# Dense layer with 512 units and ReLU activation, using L2 regularization
model.add(Dense(512, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())  # Batch normalization to normalize the activations
model.add(Dropout(0.5))  # Dropout for regularization

# Dense layer with 256 units and ReLU activation, using L2 regularization
model.add(Dense(256, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Output layer with 35 units (assuming it's a 35-class classification problem) and softmax activation
model.add(Dense(35, activation='softmax'))

# %%
# Define the optimizer with a learning rate of 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
# Compile the model with the specified optimizer, loss, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        1792
#
#  batch_normalization (Batch  (None, 32, 32, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        18464
#
#  batch_normalization_1 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 16)          4624
#
#  batch_normalization_2 (Bat  (None, 8, 8, 16)          64
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 16)          0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 35)                8995
#
# =================================================================
# Total params: 300307 (1.15 MB)
# Trainable params: 298547 (1.14 MB)
# Non-trainable params: 1760 (6.88 KB)
# _________________________________________________________________

# %%
# Specify the path to save the entire model
model_save_path = '/content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5'

# Create a ModelCheckpoint callback to save the model during training
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False
)

# Create an EarlyStopping callback to stop training early if the validation loss doesn't improve
es_callback = tf.keras.callbacks.EarlyStopping(patience=50, verbose=1)

# %%
# Function to print a message every 5 minutes
import time
def print_keep_alive():
    while True:
        print("Colab session is active.")
        time.sleep(400)  # Wait for 5 minutes

# Start the keep-alive loop in the background
import threading
keep_alive_thread = threading.Thread(target=print_keep_alive)
keep_alive_thread.daemon = True
keep_alive_thread.start()
# Out:
# Colab session is active.

# %%
# Training the custom model using the fit method
history=model.fit(train_generator,
                  steps_per_epoch=len(train_generator),
                  epochs=150,
                  validation_data=validation_generator,
                  validation_steps=len(validation_generator),
                  callbacks=[cp_callback, es_callback]
                 )
# Out:
# Epoch 1/150
#  713/1673 [===========>..................] - ETA: 5:02 - loss: 1.3087 - accuracy: 0.7607Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 1.2005 - accuracy: 0.7837Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
# Colab session is active.
#
# Epoch 1: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1673/1673 [==============================] - 6694s 4s/step - loss: 1.2005 - accuracy: 0.7837 - val_loss: 1.2870 - val_accuracy: 0.8008
# Epoch 2/150
# 1467/1673 [=========================>....] - ETA: 40s - loss: 0.9700 - accuracy: 0.8341Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.9626 - accuracy: 0.8356
# Epoch 2: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 471s 281ms/step - loss: 0.9626 - accuracy: 0.8356 - val_loss: 1.0408 - val_accuracy: 0.8698
# Epoch 3/150
# 1118/1673 [===================>..........] - ETA: 1:47 - loss: 0.8918 - accuracy: 0.8520Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.8792 - accuracy: 0.8555
# Epoch 3: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 468s 280ms/step - loss: 0.8792 - accuracy: 0.8555 - val_loss: 0.9249 - val_accuracy: 0.8792
# Epoch 4/150
#  586/1673 [=========>....................] - ETA: 3:33 - loss: 0.8602 - accuracy: 0.8608Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.8321 - accuracy: 0.8701
# Epoch 4: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 416s 249ms/step - loss: 0.8321 - accuracy: 0.8701 - val_loss: 0.9484 - val_accuracy: 0.8786
# Epoch 5/150
#  384/1673 [=====>........................] - ETA: 4:06 - loss: 0.7866 - accuracy: 0.8796Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.7904 - accuracy: 0.8806
# Epoch 5: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 465s 278ms/step - loss: 0.7904 - accuracy: 0.8806 - val_loss: 1.0558 - val_accuracy: 0.8369
# Colab session is active.
# Epoch 6/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.7686 - accuracy: 0.8851Colab session is active.
#
# Epoch 6: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 420s 251ms/step - loss: 0.7686 - accuracy: 0.8851 - val_loss: 0.9299 - val_accuracy: 0.8757
# Epoch 7/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.7494 - accuracy: 0.8890Colab session is active.
#
# Epoch 7: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 415s 248ms/step - loss: 0.7494 - accuracy: 0.8890 - val_loss: 0.8018 - val_accuracy: 0.9010
# Epoch 8/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.7246 - accuracy: 0.8942Colab session is active.
#
# Epoch 8: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 415s 248ms/step - loss: 0.7246 - accuracy: 0.8942 - val_loss: 0.7922 - val_accuracy: 0.8965
# Epoch 9/150
# 1634/1673 [============================>.] - ETA: 7s - loss: 0.7137 - accuracy: 0.8967Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.7135 - accuracy: 0.8970
# Epoch 9: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 423s 253ms/step - loss: 0.7135 - accuracy: 0.8970 - val_loss: 0.8113 - val_accuracy: 0.9033
# Epoch 10/150
# 1537/1673 [==========================>...] - ETA: 26s - loss: 0.6959 - accuracy: 0.9009Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.9010
# Epoch 10: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 466s 279ms/step - loss: 0.6955 - accuracy: 0.9010 - val_loss: 0.7199 - val_accuracy: 0.9118
# Epoch 11/150
# 1025/1673 [=================>............] - ETA: 2:04 - loss: 0.6820 - accuracy: 0.9024Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6803 - accuracy: 0.9032
# Epoch 11: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 466s 278ms/step - loss: 0.6803 - accuracy: 0.9032 - val_loss: 0.7091 - val_accuracy: 0.9169
# Epoch 12/150
#  489/1673 [=======>......................] - ETA: 3:51 - loss: 0.7041 - accuracy: 0.8963Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6781 - accuracy: 0.9031
# Epoch 12: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 467s 279ms/step - loss: 0.6781 - accuracy: 0.9031 - val_loss: 0.7280 - val_accuracy: 0.9078
# Colab session is active.
# Epoch 13/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6607 - accuracy: 0.9073Colab session is active.
#
# Epoch 13: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 476s 284ms/step - loss: 0.6607 - accuracy: 0.9073 - val_loss: 0.7670 - val_accuracy: 0.8978
# Epoch 14/150
# 1634/1673 [============================>.] - ETA: 7s - loss: 0.6523 - accuracy: 0.9095Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6523 - accuracy: 0.9098
# Epoch 14: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 469s 280ms/step - loss: 0.6523 - accuracy: 0.9098 - val_loss: 0.7128 - val_accuracy: 0.9083
# Epoch 15/150
# 1092/1673 [==================>...........] - ETA: 1:55 - loss: 0.6522 - accuracy: 0.9093Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.9098
# Epoch 15: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 472s 282ms/step - loss: 0.6454 - accuracy: 0.9098 - val_loss: 0.7237 - val_accuracy: 0.9018
# Epoch 16/150
#  741/1673 [============>.................] - ETA: 3:01 - loss: 0.6489 - accuracy: 0.9079Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6382 - accuracy: 0.9111
# Epoch 16: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 472s 282ms/step - loss: 0.6382 - accuracy: 0.9111 - val_loss: 0.7836 - val_accuracy: 0.8813
# Epoch 17/150
#  353/1673 [=====>........................] - ETA: 4:30 - loss: 0.6362 - accuracy: 0.9090Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6353 - accuracy: 0.9107Colab session is active.
#
# Epoch 17: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 478s 285ms/step - loss: 0.6353 - accuracy: 0.9107 - val_loss: 0.6475 - val_accuracy: 0.9265
# Epoch 18/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6161 - accuracy: 0.9148Colab session is active.
#
# Epoch 18: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 481s 288ms/step - loss: 0.6161 - accuracy: 0.9148 - val_loss: 0.6592 - val_accuracy: 0.9159
# Epoch 19/150
# 1495/1673 [=========================>....] - ETA: 34s - loss: 0.6149 - accuracy: 0.9165Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6168 - accuracy: 0.9159
# Epoch 19: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 472s 282ms/step - loss: 0.6168 - accuracy: 0.9159 - val_loss: 0.6138 - val_accuracy: 0.9263
# Epoch 20/150
# 1124/1673 [===================>..........] - ETA: 1:48 - loss: 0.6008 - accuracy: 0.9194Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.6011 - accuracy: 0.9188
# Epoch 20: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 419s 251ms/step - loss: 0.6011 - accuracy: 0.9188 - val_loss: 0.6395 - val_accuracy: 0.9155
# Epoch 21/150
# 1030/1673 [=================>............] - ETA: 2:06 - loss: 0.5869 - accuracy: 0.9205Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.9199
# Epoch 21: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 474s 283ms/step - loss: 0.5876 - accuracy: 0.9199 - val_loss: 0.6270 - val_accuracy: 0.9200
# Epoch 22/150
#  520/1673 [========>.....................] - ETA: 3:42 - loss: 0.5904 - accuracy: 0.9190Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.9176
# Epoch 22: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 425s 254ms/step - loss: 0.5946 - accuracy: 0.9176 - val_loss: 0.6319 - val_accuracy: 0.9268
# Epoch 23/150
#  374/1673 [=====>........................] - ETA: 4:20 - loss: 0.5840 - accuracy: 0.9212Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5826 - accuracy: 0.9203
# Epoch 23: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 471s 281ms/step - loss: 0.5826 - accuracy: 0.9203 - val_loss: 0.6358 - val_accuracy: 0.9159
# Epoch 24/150
#   22/1673 [..............................] - ETA: 5:42 - loss: 0.6229 - accuracy: 0.9148Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.9209Colab session is active.
#
# Epoch 24: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 476s 284ms/step - loss: 0.5811 - accuracy: 0.9209 - val_loss: 0.6413 - val_accuracy: 0.9131
# Epoch 25/150
# 1531/1673 [==========================>...] - ETA: 28s - loss: 0.5702 - accuracy: 0.9211Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5700 - accuracy: 0.9214
# Epoch 25: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 473s 283ms/step - loss: 0.5700 - accuracy: 0.9214 - val_loss: 0.5970 - val_accuracy: 0.9222
# Epoch 26/150
# 1171/1673 [===================>..........] - ETA: 1:38 - loss: 0.5691 - accuracy: 0.9223Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5709 - accuracy: 0.9218
# Epoch 26: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 470s 281ms/step - loss: 0.5709 - accuracy: 0.9218 - val_loss: 0.6547 - val_accuracy: 0.9103
# Epoch 27/150
#  655/1673 [==========>...................] - ETA: 3:19 - loss: 0.5680 - accuracy: 0.9222Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5625 - accuracy: 0.9237
# Epoch 27: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 408s 244ms/step - loss: 0.5625 - accuracy: 0.9237 - val_loss: 0.5952 - val_accuracy: 0.9190
# Epoch 28/150
#  585/1673 [=========>....................] - ETA: 3:43 - loss: 0.5576 - accuracy: 0.9259Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5554 - accuracy: 0.9260
# Epoch 28: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 480s 287ms/step - loss: 0.5554 - accuracy: 0.9260 - val_loss: 0.6805 - val_accuracy: 0.8967
# Epoch 29/150
#  207/1673 [==>...........................] - ETA: 4:47 - loss: 0.5528 - accuracy: 0.9260Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5413 - accuracy: 0.9281Colab session is active.
#
# Epoch 29: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 469s 280ms/step - loss: 0.5413 - accuracy: 0.9281 - val_loss: 0.6041 - val_accuracy: 0.9145
# Epoch 30/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5519 - accuracy: 0.9246Colab session is active.
#
# Epoch 30: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 413s 247ms/step - loss: 0.5519 - accuracy: 0.9246 - val_loss: 0.6048 - val_accuracy: 0.9198
# Epoch 31/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5402 - accuracy: 0.9260Colab session is active.
#
# Epoch 31: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 469s 280ms/step - loss: 0.5402 - accuracy: 0.9260 - val_loss: 0.6213 - val_accuracy: 0.9161
# Epoch 32/150
# 1149/1673 [===================>..........] - ETA: 1:42 - loss: 0.5487 - accuracy: 0.9244Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5447 - accuracy: 0.9260
# Epoch 32: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 471s 281ms/step - loss: 0.5447 - accuracy: 0.9260 - val_loss: 0.5773 - val_accuracy: 0.9269
# Epoch 33/150
#  634/1673 [==========>...................] - ETA: 3:20 - loss: 0.5298 - accuracy: 0.9309Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5247 - accuracy: 0.9306
# Epoch 33: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 412s 247ms/step - loss: 0.5247 - accuracy: 0.9306 - val_loss: 0.5981 - val_accuracy: 0.9199
# Epoch 34/150
#  547/1673 [========>.....................] - ETA: 3:46 - loss: 0.5452 - accuracy: 0.9256Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.9270
# Epoch 34: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 470s 281ms/step - loss: 0.5371 - accuracy: 0.9270 - val_loss: 0.5680 - val_accuracy: 0.9200
# Epoch 35/150
#  199/1673 [==>...........................] - ETA: 4:59 - loss: 0.5416 - accuracy: 0.9237Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5255 - accuracy: 0.9282
# Epoch 35: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 423s 253ms/step - loss: 0.5255 - accuracy: 0.9282 - val_loss: 0.5824 - val_accuracy: 0.9184
# Colab session is active.
# Epoch 36/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5258 - accuracy: 0.9277Colab session is active.
#
# Epoch 36: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 473s 282ms/step - loss: 0.5258 - accuracy: 0.9277 - val_loss: 0.7547 - val_accuracy: 0.8721
# Epoch 37/150
# 1611/1673 [===========================>..] - ETA: 12s - loss: 0.5157 - accuracy: 0.9319Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.9319
# Epoch 37: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 482s 288ms/step - loss: 0.5144 - accuracy: 0.9319 - val_loss: 0.5474 - val_accuracy: 0.9291
# Epoch 38/150
# 1129/1673 [===================>..........] - ETA: 1:48 - loss: 0.5186 - accuracy: 0.9289Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.9292
# Epoch 38: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 424s 254ms/step - loss: 0.5186 - accuracy: 0.9292 - val_loss: 0.5740 - val_accuracy: 0.9204
# Epoch 39/150
# 1019/1673 [=================>............] - ETA: 2:08 - loss: 0.5196 - accuracy: 0.9285Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5182 - accuracy: 0.9291
# Epoch 39: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 469s 280ms/step - loss: 0.5182 - accuracy: 0.9291 - val_loss: 0.5427 - val_accuracy: 0.9294
# Epoch 40/150
#  502/1673 [========>.....................] - ETA: 3:49 - loss: 0.5130 - accuracy: 0.9305Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5127 - accuracy: 0.9290
# Epoch 40: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 478s 286ms/step - loss: 0.5127 - accuracy: 0.9290 - val_loss: 0.5456 - val_accuracy: 0.9279
# Colab session is active.
# Epoch 41/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5064 - accuracy: 0.9308Colab session is active.
#
# Epoch 41: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 465s 278ms/step - loss: 0.5064 - accuracy: 0.9308 - val_loss: 0.5642 - val_accuracy: 0.9236
# Epoch 42/150
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5063 - accuracy: 0.9315Colab session is active.
#
# Epoch 42: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 465s 278ms/step - loss: 0.5063 - accuracy: 0.9315 - val_loss: 0.5686 - val_accuracy: 0.9203
# Epoch 43/150
# 1366/1673 [=======================>......] - ETA: 1:00 - loss: 0.5094 - accuracy: 0.9302Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.5073 - accuracy: 0.9302
# Epoch 43: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 468s 280ms/step - loss: 0.5073 - accuracy: 0.9302 - val_loss: 0.5398 - val_accuracy: 0.9278
# Epoch 44/150
# 1019/1673 [=================>............] - ETA: 2:07 - loss: 0.4964 - accuracy: 0.9315Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.9312
# Epoch 44: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 470s 281ms/step - loss: 0.4997 - accuracy: 0.9312 - val_loss: 0.5581 - val_accuracy: 0.9222
# Epoch 45/150
#  500/1673 [=======>......................] - ETA: 3:47 - loss: 0.5038 - accuracy: 0.9312Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.4942 - accuracy: 0.9329
# Epoch 45: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 413s 247ms/step - loss: 0.4942 - accuracy: 0.9329 - val_loss: 0.5291 - val_accuracy: 0.9269
# Epoch 46/150
#  431/1673 [======>.......................] - ETA: 4:03 - loss: 0.4816 - accuracy: 0.9347Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.9323
# Epoch 46: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 483s 289ms/step - loss: 0.4899 - accuracy: 0.9323 - val_loss: 0.5489 - val_accuracy: 0.9270
# Epoch 47/150
#   12/1673 [..............................] - ETA: 4:32 - loss: 0.4944 - accuracy: 0.9453Colab session is active.
# 1673/1673 [==============================] - ETA: 0s - loss: 0.4954 - accuracy: 0.9322Colab session is active.
#
# Epoch 47: saving model to /content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5
# 1673/1673 [==============================] - 464s 277ms/step - loss: 0.4954 - accuracy: 0.9322 - val_loss: 0.5337 - val_accuracy: 0.9330
# Epoch 48/150
# 1219/1673 [====================>.........] - ETA: 1:28 - loss: 0.4923 - accuracy: 0.9314

# %% [markdown]
# # An example image with the augmentations applied

# %%
#Import necessary libraries
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# Image path
img_path = '/content/drive/MyDrive/DS/Test_NEW_SK_A_Z_1_9/1/010.png'

# Load and preprocess the image
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = img_array.reshape((1,) + img_array.shape)  # Reshape to (1, height, width, channels)

# Data augmentation parameters
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.7, 1.3]
)

# Generate augmented images
augmented_images = []

# Apply each augmentation and store the augmented images
for i in range(9):  # Generate 9 augmented images
    augmented_img = next(datagen.flow(img_array, batch_size=1))[0]
    augmented_images.append(augmented_img)

# Titles for each augmented image
titles = [
    "Original Image",
    "Rotated Image",
    "Width Shifted Image",
    "Height Shifted Image",
    "Sheared Image",
    "Zoomed Image",
    "Horizontally Flipped Image",
    "Vertically Flipped Image",
    "Brightness Adjusted Image"
]

# Display the images
plt.figure(figsize=(15, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[i])
    plt.title(titles[i])
    plt.axis('off')

plt.show()

# %% [markdown]
# # Custom Model Feature Visualization

# %%
#Import necessary libraries
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
import numpy as np
from tensorflow.keras.models import load_model


# Assuming your model is named 'model_1'
model_1 = load_model('/content/drive/MyDrive/DS/Demodata/OwnModel_15Oct_A_Z_1_9.h5')
layer_names = ['conv2d', 'conv2d_1', 'conv2d_2']  # Names of the convolutional layers you want to visualize
num_layers = len(layer_names)

# Create a new model that outputs the intermediate layer activations
activation_models = [Model(inputs=model_1.inputs, outputs=model_1.get_layer(layer_name).output) for layer_name in layer_names]

# Load an example image (replace this with your own image data)
example_image = np.random.random((1, 32, 32, 3))

# Get the intermediate layer activations for the example image
activations = [activation_model.predict(example_image) for activation_model in activation_models]

# Plot the feature maps
for i in range(num_layers):
    plt.figure(figsize=(8, 8))
    for j in range(activations[i].shape[-1]):
        plt.subplot(8, 8, j + 1)
        plt.imshow(activations[i][0, :, :, j], cmap='viridis')
        plt.axis('off')
    plt.suptitle(f'Layer: {layer_names[i]}')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 104ms/step
